# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

table = pd.read_csv('penduduk_gender_head.csv')
table.head()
x_label = table['NAMA KELURAHAN']
plt.figure(figsize=(12,8))
plt.bar(x=np.arange(len(x_label)), height=table['LAKI-LAKI WNI'])
plt.xticks(np.arange(len(x_label)), table['NAMA KELURAHAN'], rotation=30)
plt.show()

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

table = pd.read_csv('penduduk_gender_head.csv')
table.head()

x_label = table['NAMA KELURAHAN']
plt.figure(figsize=(20,10))
plt.bar(x=np.arange(len(x_label)), height=table['LAKI-LAKI WNA'])
plt.xticks(np.arange(len(x_label)), table['NAMA KELURAHAN'], rotation=90)
plt.xlabel('Kelurahan di Jakarta Pusat')
plt.ylabel('Jumlah penduduk laki-laki wna')
plt.title('Persebaran WNA Asing Laki-laki Di Jakarta')

plt.show()

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
